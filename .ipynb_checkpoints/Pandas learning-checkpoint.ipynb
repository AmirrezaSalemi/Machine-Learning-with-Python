# %%
import pandas as pd

# %%
df = pd.DataFrame(
    {
        'Age': [20, 22, 23],
        'Weight': [83, 74, 68],
        'Heigth': [165, 186, 192]
    }
)

# %%
df.to_csv('test.csv', index=False)

# %%
df.plot.scatter(x = 'Heigth', y = 'Weight', color='red')
# Out:
# <Axes: xlabel='Heigth', ylabel='Weight'>
